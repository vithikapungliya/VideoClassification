# %%
# ! cp kaggle.json ~/.kaggle/
# ! chmod 600 ~/.kaggle/kaggle.json
# !  kaggle datasets download -d pevogam/ucf101
# Out:
# Downloading ucf101.zip to /content
# 100% 6.48G/6.49G [01:04<00:00, 141MB/s]
# 100% 6.49G/6.49G [01:04<00:00, 108MB/s]

# %%
# !unzip "/content/ucf101.zip" -d "/content/drive/MyDrive/UCF101"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
main_dir="/content/drive/MyDrive/edi_TY/AVDatasetVideos"

# %%
df=pd.read_csv('/content/drive/MyDrive/edi_TY/final675.csv')

# %%
df
# Out:
#      Unnamed: 0  Class_No                       Caption Category  \
# 0             0       205                   pig oinking  animals
# 1             1       121                 goose honking  animals
# 2             2        81              pheasant crowing  animals
# 3             3       135                canary calling  animals
# 4             6       274              cat caterwauling  animals
# ..          ...       ...                           ...      ...
# 572         669        74                airplane flyby  vehicle
# 573         670       201  opening or closing car doors  vehicle
# 574         671         0               ambulance siren  vehicle
# 575         672        37            police car (siren)  vehicle
# 576         674        38         race car, auto racing  vehicle
#
#                       Video               VideoName
# 0    CTSTTr0Gjdc_000070.mp4  CTSTTr0Gjdc_000070.mp4
# 1    c6VTdTPcsp0_000030.mp4  c6VTdTPcsp0_000030.mp4
# 2    FZq-Xe11dw8_000112.mp4  FZq-Xe11dw8_000112.mp4
# 3    kHm7vCLSxkQ_000013.mp4  kHm7vCLSxkQ_000013.mp4
# 4    Bh6-tESNv9k_000051.mp4  Bh6-tESNv9k_000051.mp4
# ..                      ...                     ...
# 572  YxvrAkrnbWw_000107.mp4  YxvrAkrnbWw_000107.mp4
# 573  9Z7eOphQr0s_000042.mp4  9Z7eOphQr0s_000042.mp4
# 574  AhxTt62ITis_000166.mp4  AhxTt62ITis_000166.mp4
# 575  kmiRFMZtLdM_000000.mp4  kmiRFMZtLdM_000000.mp4
# 576  Hd9z1A9DbYM_000000.mp4  Hd9z1A9DbYM_000000.mp4
#
# [577 rows x 6 columns]

# %%
df['Duration']=0

# %%
df
# Out:
#      Unnamed: 0  Class_No                       Caption Category  \
# 0             0       205                   pig oinking  animals
# 1             1       121                 goose honking  animals
# 2             2        81              pheasant crowing  animals
# 3             3       135                canary calling  animals
# 4             6       274              cat caterwauling  animals
# ..          ...       ...                           ...      ...
# 572         669        74                airplane flyby  vehicle
# 573         670       201  opening or closing car doors  vehicle
# 574         671         0               ambulance siren  vehicle
# 575         672        37            police car (siren)  vehicle
# 576         674        38         race car, auto racing  vehicle
#
#                       Video               VideoName  Duration
# 0    CTSTTr0Gjdc_000070.mp4  CTSTTr0Gjdc_000070.mp4         0
# 1    c6VTdTPcsp0_000030.mp4  c6VTdTPcsp0_000030.mp4         0
# 2    FZq-Xe11dw8_000112.mp4  FZq-Xe11dw8_000112.mp4         0
# 3    kHm7vCLSxkQ_000013.mp4  kHm7vCLSxkQ_000013.mp4         0
# 4    Bh6-tESNv9k_000051.mp4  Bh6-tESNv9k_000051.mp4         0
# ..                      ...                     ...       ...
# 572  YxvrAkrnbWw_000107.mp4  YxvrAkrnbWw_000107.mp4         0
# 573  9Z7eOphQr0s_000042.mp4  9Z7eOphQr0s_000042.mp4         0
# 574  AhxTt62ITis_000166.mp4  AhxTt62ITis_000166.mp4         0
# 575  kmiRFMZtLdM_000000.mp4  kmiRFMZtLdM_000000.mp4         0
# 576  Hd9z1A9DbYM_000000.mp4  Hd9z1A9DbYM_000000.mp4         0
#
# [577 rows x 7 columns]

# %%
from moviepy.editor import VideoFileClip
def dur(filename):
    
    clip = VideoFileClip(f'/content/drive/MyDrive/edi_TY/AVDatasetVideos/{filename}')
    duration       = clip.duration
    print(duration)
    return duration

# %%
df['Duration']=df['VideoName'].apply(dur)

# %%
df
# Out:
#      Unnamed: 0  Class_No                       Caption Category  \
# 0             0       205                   pig oinking  animals
# 1             1       121                 goose honking  animals
# 2             2        81              pheasant crowing  animals
# 3             3       135                canary calling  animals
# 4             6       274              cat caterwauling  animals
# ..          ...       ...                           ...      ...
# 572         669        74                airplane flyby  vehicle
# 573         670       201  opening or closing car doors  vehicle
# 574         671         0               ambulance siren  vehicle
# 575         672        37            police car (siren)  vehicle
# 576         674        38         race car, auto racing  vehicle
#
#                       Video               VideoName  Duration
# 0    CTSTTr0Gjdc_000070.mp4  CTSTTr0Gjdc_000070.mp4     99.57
# 1    c6VTdTPcsp0_000030.mp4  c6VTdTPcsp0_000030.mp4     48.51
# 2    FZq-Xe11dw8_000112.mp4  FZq-Xe11dw8_000112.mp4    124.20
# 3    kHm7vCLSxkQ_000013.mp4  kHm7vCLSxkQ_000013.mp4     50.06
# 4    Bh6-tESNv9k_000051.mp4  Bh6-tESNv9k_000051.mp4     73.28
# ..                      ...                     ...       ...
# 572  YxvrAkrnbWw_000107.mp4  YxvrAkrnbWw_000107.mp4    180.26
# 573  9Z7eOphQr0s_000042.mp4  9Z7eOphQr0s_000042.mp4     67.15
# 574  AhxTt62ITis_000166.mp4  AhxTt62ITis_000166.mp4    522.33
# 575  kmiRFMZtLdM_000000.mp4  kmiRFMZtLdM_000000.mp4     21.41
# 576  Hd9z1A9DbYM_000000.mp4  Hd9z1A9DbYM_000000.mp4     87.26
#
# [577 rows x 7 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0    Class_No     Duration
# count  577.000000  577.000000   577.000000
# mean   338.873484  119.675910   249.160260
# std    196.142919   74.377444   287.018773
# min      0.000000    0.000000     9.010000
# 25%    173.000000   61.000000    68.890000
# 50%    335.000000  109.000000   154.640000
# 75%    510.000000  173.000000   338.800000
# max    674.000000  298.000000  3652.030000

# %%
import os

# %%
os.listdir(main_dir)

# %%
import pandas as pd
import numpy as np
import os
import cv2

# %%
def framing(video):#defining a small function named"framing" with a parameter "i" that's supposed to be provided for reading the video
    fr = []#creating an empty list named fr
    fr_pre=[]#creating an empty list named fr_pre
    cap = cv2.VideoCapture(video)#reading the video file
    clip = VideoFileClip(video)  
    clip = clip.subclip(0, 15)
    while (cap.isOpened()):#This command builds a loop to check if the data is still being read from the video
        ret,frame = cap.read()#reading the data tunnel,gives two output where one tells about presence of frames(here it's ret) & the other speaks frame data(here it's frame)
        if ret == True:#checking for presence of frames
            # cv2_imshow(frame)#displaying the frames
            grayed = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)#Converting the frames to Grayscale from BGR
            canned = cv2.Canny(grayed,320,320)#For extrating edges we use Canny Edge detection method
            fr.append(frame)#Appending the read frame
            fr_pre.append(canned)#Appending the edge extracted frames
            # cv2_imshow(grayed)#Displaying the original frames
            # cv2_imshow(canned)#Displaying the edge detected frames
            k = cv2.waitKey(10) & 0XFF#this is an arrangement for displaying the video where the secs for which each frame needs to be displayed in given in the paranthesis
            if k == ord('q'):#pressing 'q' key will close the video
                break
        else:
            break
    cap.release()#Here we release the resoures
    cv2.destroyAllWindows()#Here we delete all the windows that were created during the program       
    return fr_pre,fr     #returning the frames received after the execution of function

# %%
def difference_of_frames(frames):
    diff = []#creatin a list variable
    for i in range(0,len(frames)-1):#defining the range
        # print(frames[i],frames[i+1])#checking the frames presence
        diff.append(cv2.absdiff(frames[i],frames[i+1]))#appending the diff between frames to the list variable so we're supposed to get only the difference between frames
    return diff

# %%
def cal_threshold(diff):
  mn = np.mean(diff)#This gives mean
  st_d = np.std(diff)#This gives standard deviation
  a = 4#Setting a random value we can modify it to any value 
  ts = mn + (a * st_d)#defining the standard threshold value for the project/global threshold value
  return ts

# %%
def imp_frames(diff, ts, ogframes):
  a_fr = []#Creating an empty list
  for i in range(len(diff)):#Defining the for loop to be looped over all the frames obtained after finding the frames resulted from subtracting
      mn = np.mean(diff[i])#Calculating the mean for each frame
      st_d = np.std(diff[i])#Calculating the standard deviation for each frame
      fr_ts = mn + (4*st_d)#Finding the threshold values for each frame/image
      a_fr.append([i,fr_ts])#Appending the frame number & the threshold values
  imp_fr = []#Creating an empty list
  for i,ac_tr in(a_fr):#Defining the loop on the list obtained from above code
      if ac_tr >= ts:#Comapring the threshold values to the standard threshold/global threshold values
          imp_fr.append([i,ac_tr])#Appending the list with the imp frames based on their index & the values
  key_fr = []#Creating an empty list
  for i,_ in imp_fr:#Defining the loop over the list obtained from above code
      key_fr.append(ogframes[i])#This extracts the frames based on the index of frames 
  return key_fr

# %%
pip install imageio-ffmpeg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.7/dist-packages (0.4.7)

# %%
# !pip3 install imageio==2.4.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio==2.4.1 in /usr/local/lib/python3.7/dist-packages (2.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from imageio==2.4.1) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from imageio==2.4.1) (1.21.6)

# %%
from moviepy.editor import VideoFileClip

# %%
from moviepy.editor import *

# %%
for i,row in df.iterrows():
  try:
    if(row['Duration']<60):
        path= os.path.join(main_dir,row['VideoName'])
        frames,ogframes = framing(path)#calling function framing & then extracting the images 
        diff=difference_of_frames(frames)  
        ts=cal_threshold(diff) 
        key_fr=imp_frames(diff, ts, ogframes)  
        frame_no=key_fr[int(len(key_fr)/2)] #this is a frame
        x=row['VideoName'][:-4] 
        cv2.imwrite(f"/content/drive/MyDrive/edi_TY/keyFramesAV/{x}.jpg",frame_no)
        cv2.destroyAllWindows()
        print(i)
  except:
    continue
